# %% [markdown]
# # Experiment EXP-NUMBER: TITLE
#
# > **AsciiDoc report:** [`NUMBER-SLUG.adoc`](NUMBER-SLUG.adoc)
# > **Date started:** DATE
# > **Status:** ACTIVE
#
# ---
#
# This notebook is the interactive companion to the experiment AsciiDoc report.
# Use it for data exploration, code prototyping, and generating plots.
# Record your conclusions in the AsciiDoc report.

# %% [markdown]
# ## Hypothesis
#
# > *"We believe that [approach] will [outcome] for [users/system], because [rationale]."*

# %% [markdown]
# ## Setup

# %%
# Standard imports — add or remove as needed for your experiment
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)

print(f"Experiment EXP-NUMBER: TITLE")
print(f"NumPy {np.__version__} | Pandas {pd.__version__}")

# %% [markdown]
# ## Data

# %%
# TODO: Load your data here
# df = pd.read_csv('data/raw/dataset.csv')
# df.head()

# %% [markdown]
# ## Experiment

# %%
# TODO: Implement your experiment here

# %% [markdown]
# ## Results & Observations

# %%
# TODO: Generate plots and metrics here
# plt.figure(figsize=(10, 6))
# plt.title('Experiment EXP-NUMBER Results')
# plt.show()

# %% [markdown]
# ## Conclusion
#
# **Outcome:** [SUCCEEDED / FAILED / INCONCLUSIVE]
#
# - **Decision:** _TODO: What was decided as a result of this experiment?_
# - **Next Steps:** _TODO: Promote to ADR, run a follow-up, or abandon the approach._
#
# > Update the AsciiDoc report [`NUMBER-SLUG.adoc`](NUMBER-SLUG.adoc) with these conclusions.
